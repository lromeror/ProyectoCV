# %%
import pandas as pd

# %%
df = pd.read_csv("assets/data/planificacion.csv",sep=",")
df
# Out:
#                                                 NOMBRE       BLOQUE
# 0                                         QUIMIOMETRIA           9M  \
# 1    DISEÑO DE CIMENTACIONES SUPERFICIALES Y PROFUNDAS           9M
# 2         INTRODUCCIÓN A LA INDUSTRIA HIDROCARBURÍFERA          13H
# 3                        ESTRATIGRAFIA Y SEDIMENTACIÓN          13H
# 4                                 PATOLOGÍA ACUÍCOLA I           5K
# ..                                                 ...          ...
# 847                PROCESAMIENTO DE FRUTAS Y VEGETALES          12G
# 848     PROCESAMIENTO DE CÁRNICOS, PESCADOS Y MARISCOS          12G
# 849                           PROCESAMIENTO DE LÁCTEOS          12G
# 850                                   INVESTIGACIÓN II  AULAS EDCOM
# 851                                    INVESTIGACIÓN I  AULAS EDCOM
#
#              Coordenadas     LATS     LONGS
# 0    -2.14682, -79.96671 -2.14682 -79.96671
# 1    -2.14682, -79.96671 -2.14682 -79.96671
# ...

# %%
df = df[df['BLOQUE']!="CENAIM"].copy()
df
# Out:
#                                                 NOMBRE       BLOQUE
# 0                                         QUIMIOMETRIA           9M  \
# 1    DISEÑO DE CIMENTACIONES SUPERFICIALES Y PROFUNDAS           9M
# 2         INTRODUCCIÓN A LA INDUSTRIA HIDROCARBURÍFERA          13H
# 3                        ESTRATIGRAFIA Y SEDIMENTACIÓN          13H
# 4                                 PATOLOGÍA ACUÍCOLA I           5K
# ..                                                 ...          ...
# 847                PROCESAMIENTO DE FRUTAS Y VEGETALES          12G
# 848     PROCESAMIENTO DE CÁRNICOS, PESCADOS Y MARISCOS          12G
# 849                           PROCESAMIENTO DE LÁCTEOS          12G
# 850                                   INVESTIGACIÓN II  AULAS EDCOM
# 851                                    INVESTIGACIÓN I  AULAS EDCOM
#
#              Coordenadas     LATS     LONGS
# 0    -2.14682, -79.96671 -2.14682 -79.96671
# 1    -2.14682, -79.96671 -2.14682 -79.96671
# ...

# %%
df[df['BLOQUE']!="CENAIM"]
# Out:
# array(['9M', '13H', '5K', '13C', 'FCNM', '12E', '9F', 'FCSH', 'FICT',
#        '12H', 'FIEC', '8G', '9I', '13G', '11A', '13B', '3H', 'GEA', '9C',
#        '14B', '11D', '11F', '9B', '3D', 'FADCOM', 'FIMCP', '12C', '11B',
#        '8E', '11C', '13D', 'DEPORTES', 'VRA', '8F', '8B', 'FIMCM',
#        'BLOQUE A', '7A', '8H', '7B', '9G', 'FCV', '12G', 'AULAS EDCOM'],
#       dtype=object)

# %%
df[df["BLOQUE"]=="GEA"]
# Out:
#                                                 NOMBRE BLOQUE
# 76                                PRODUCCIÓN VEGETAL I    GEA  \
# 83                                     AGROECOSISTEMAS    GEA
# 145  MATERIA INTEGRADORA DE INGENIERÍA AGRÍCOLA Y B...    GEA
# 837                 DIAGNÓSTICO Y PROTECCIÓN VEGETAL I    GEA
# 838                                         GENOTECNIA    GEA
# 839                                      EXTENSIONISMO    GEA
# 840                                    RIEGO Y DRENAJE    GEA
# 841                             PRODUCCIÓN PECUARIA II    GEA
#
#              Coordenadas     LATS     LONGS
# 76   -2.15133, -79.95574 -2.15133 -79.95574
# 83   -2.15133, -79.95574 -2.15133 -79.95574
# 145  -2.15133, -79.95574 -2.15133 -79.95574
# 837  -2.15133, -79.95574 -2.15133 -79.95574
# 838  -2.15133, -79.95574 -2.15133 -79.95574
# 839  -2.15133, -79.95574 -2.15133 -79.95574
# 840  -2.15133, -79.95574 -2.15133 -79.95574
# 841  -2.15133, -79.95574 -2.15133 -79.95574

# %%
max(df["LATS"]) , min(df["LATS"])
# Out:
# (-1.95497, -2.15393)

# %%
max(df['LONGS']),min(df['LONGS'])
# Out:
# (-79.9464, -80.72931)
